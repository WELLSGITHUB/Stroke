# %% [markdown]
# ### Import libraries and create data frame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from imblearn.over_sampling import SMOTE
from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Prepare Data

# %%
stroke_df = pd.read_csv("Resources/healthcare-dataset-stroke-data.csv")
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Display the cleaned DataFrame and its data types
display(stroke_df.head())
print(stroke_df.dtypes)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
print(stroke_df.columns)
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
stroke_df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
# only 3% of the data is missing bmi data so we drop it
stroke_df = stroke_df.dropna()

# only one row with gender other so we drop it
stroke_df = stroke_df[stroke_df['gender'] != 'Other']

# %% [markdown]
# ### Split into X and y

# %%
X = stroke_df.drop(columns=['id', 'stroke'])
X.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban             228.69  36.6  formerly smoked
# 2          Rural             105.92  32.5     never smoked
# 3          Urban             171.23  34.4           smokes
# 4          Rural             174.12  24.0     never smoked
# 5          Urban             186.21  29.0  formerly smoked

# %%
y = stroke_df['stroke']

# %% [markdown]
# ### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
X_train.isna().sum()/len(stroke_df)
# Out:
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# dtype: float64

# %%
(X_train['smoking_status'] == 'Unknown').sum()/len(stroke_df)
# Out:
# 0.22432762836185818

# %%
X_train.isna().sum()/len(stroke_df)
# Out:
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# dtype: float64

# %%
X_train.loc[X_train['smoking_status'] == 'Unknown'].describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  1101.000000   1101.000000    1101.000000        1101.000000
# mean     29.758946      0.024523       0.028156          98.191499
# std      24.718526      0.154737       0.165494          35.406038
# min       0.080000      0.000000       0.000000          55.230000
# 25%       8.000000      0.000000       0.000000          76.110000
# 50%      23.000000      0.000000       0.000000          89.280000
# 75%      50.000000      0.000000       0.000000         109.560000
# max      82.000000      1.000000       1.000000         254.600000
#
#                bmi
# count  1101.000000
# mean     25.713715
# std       7.952527
# min      11.300000
# 25%      19.500000
# 50%      24.600000
# 75%      30.200000
# max      61.200000

# %%
X_train.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  3681.000000   3681.000000    3681.000000        3681.000000
# mean     43.019723      0.089378       0.052703         104.820277
# std      22.433095      0.285327       0.223470          44.210654
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          76.560000
# 50%      45.000000      0.000000       0.000000          91.540000
# 75%      60.000000      0.000000       0.000000         112.770000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi
# count  3681.000000
# mean     29.023200
# std       7.814099
# min      11.300000
# 25%      23.800000
# 50%      28.200000
# 75%      33.300000
# max      92.000000

# %%
X_train['age'].plot(kind='hist',alpha=0.2)
X_train.loc[stroke_df['smoking_status'] == 'Unknown', 'age'].plot(kind='hist')
plt.title('Age Distribution of All vs Those with Unknown Smoking Status')
plt.xlabel('Age')
plt.savefig('age_distribution_plot.png')

# %%
# We will assume most of the unknown values below the legal smoking age fall into the never smoked category
for index, row in X_train.iterrows():
    if row['age'] <= 18:
        X_train.at[index, 'smoking_status'] = 'never smoked'

(X_train['smoking_status'] == 'Unknown').sum()/len(stroke_df)
# Out:
# 0.12082314588427058

# %%
'''
for x in stroke_df:
    display(stroke_df[x].value_counts())
'''
# Out:
# '\nfor x in stroke_df:\n    display(stroke_df[x].value_counts())\n'

# %% [markdown]
# ### Scale The Data

# %%
scaler = StandardScaler()
col_scale = ['age', 'bmi', 'avg_glucose_level']
#Fit the scaler to the columnsint he training set
X_train[col_scale]=scaler.fit_transform(X_train[col_scale])
#Transform
X_test[col_scale]=scaler.fit_transform(X_test[col_scale])

# %%
X_train.head()
# Out:
#       gender       age  hypertension  heart_disease ever_married work_type  \
# 271   Female  0.266619             0              0          Yes   Private
# 2604    Male  0.757033             0              0          Yes   Private
# 4894  Female -0.402127             0              0           No  Govt_job
# 1372    Male -0.090045             0              0          Yes   Private
# 3894  Female -1.892984             0              0           No  children
#
#      Residence_type  avg_glucose_level       bmi   smoking_status
# 271           Rural          -1.008950  0.317009           smokes
# 2604          Rural          -0.383676 -0.002969  formerly smoked
# 4894          Urban          -0.570535  2.211278     never smoked
# 1372          Rural          -0.068551 -0.297349          Unknown
# 3894          Urban          -0.540673 -1.372475     never smoked

# %% [markdown]
# ## Encode the dataset

# %%
#encode# List 
categorical_columns = ['gender', 'ever_married', 'work_type', 'Residence_type']

#One-Hot Encoding with pd.get_dummies
X_train_encoded = pd.get_dummies(X_train, columns=categorical_columns, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_columns, drop_first=True)

#Check the data
X_train_encoded.head()
#X_train_encoded.isna().sum()/len(stroke_df)
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 271   0.266619             0              0          -1.008950  0.317009
# 2604  0.757033             0              0          -0.383676 -0.002969
# 4894 -0.402127             0              0          -0.570535  2.211278
# 1372 -0.090045             0              0          -0.068551 -0.297349
# 3894 -1.892984             0              0          -0.540673 -1.372475
#
#        smoking_status  gender_Male  ever_married_Yes  work_type_Never_worked  \
# 271            smokes        False              True                   False
# 2604  formerly smoked         True              True                   False
# 4894     never smoked        False             False                   False
# 1372          Unknown         True              True                   False
# 3894     never smoked        False             False                   False
#
#       work_type_Private  work_type_Self-employed  work_type_children  \
# 271                True                    False               False
# 2604               True                    False               False
# 4894              False                    False               False
# 1372               True                    False               False
# 3894              False                    False                True
#
#       Residence_type_Urban
# 271                  False
# 2604                 False
# 4894                  True
# 1372                 False
# 3894                  True

# %%
# Create an encoder for the backpack_color column
smoke_ord_enc = OrdinalEncoder(categories = [['smokes','formerly smoked','never smoked']],encoded_missing_value = -1,
                               handle_unknown = 'use_encoded_value', unknown_value = -1) 
#PUT CATEGORIES IN ORDER LOWEST TO HIGHEST ORDER

# Train the encoder
smoke_ord_enc.fit(X_train['smoking_status'].values.reshape(-1,1))
# Out:
# OrdinalEncoder(categories=[['smokes', 'formerly smoked', 'never smoked']],
#                encoded_missing_value=-1, handle_unknown='use_encoded_value',
#                unknown_value=-1)

# %%
X_train_encoded['smoking_status_ordinal'] = smoke_ord_enc.fit_transform(X_train_encoded['smoking_status'].values.reshape(-1,1))
X_test_encoded['smoking_status_ordinal'] = smoke_ord_enc.fit_transform(X_test_encoded['smoking_status'].values.reshape(-1,1))

# %%
X_test_encoded.tail(10)
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 1305  0.069121             0              0          -0.427209 -0.239740
# 4083  0.112760             0              0          -0.310186 -0.779855
# 1495 -0.061796             0              0          -0.052600  0.212449
# 509  -0.149074             0              0          -0.487165  0.903293
# 4722  1.552852             1              0           1.013715  0.413422
# 4407 -0.367270             0              0          -0.796267  3.415455
# 2107  0.418234             1              0           1.409863 -0.164376
# 2228  0.243678             1              0           1.738063 -0.302545
# 998  -0.585466             0              0          -0.734091 -0.943146
# 1877 -1.720084             0              0          -0.640828 -1.282288
#
#        smoking_status  gender_Male  ever_married_Yes  work_type_Never_worked  \
# 1305     never smoked         True              True                   False
# 4083          Unknown        False              True                   False
# 1495     never smoked        False              True                   False
# 509      never smoked        False              True                   False
# 4722     never smoked        False              True                   False
# 4407  formerly smoked        False             False                   False
# 2107  formerly smoked        False             False                   False
# 2228     never smoked         True              True                   False
# 998           Unknown        False             False                   False
# 1877          Unknown        False             False                   False
#
#       work_type_Private  work_type_Self-employed  work_type_children  \
# 1305              False                    False               False
# 4083              False                     True               False
# 1495               True                    False               False
# 509                True                    False               False
# 4722              False                     True               False
# 4407               True                    False               False
# 2107               True                    False               False
# 2228               True                    False               False
# 998                True                    False               False
# 1877              False                    False                True
#
#       Residence_type_Urban  smoking_status_ordinal
# 1305                 False                     2.0
# 4083                  True                    -1.0
# 1495                 False                     2.0
# 509                  False                     2.0
# 4722                 False                     2.0
# 4407                  True                     1.0
# 2107                 False                     1.0
# 2228                  True                     2.0
# 998                   True                    -1.0
# 1877                 False                    -1.0

# %%
X_train_encoded = X_train_encoded.drop(['smoking_status'], axis=1)
X_test_encoded = X_test_encoded.drop(['smoking_status'], axis=1)

# %%
X_test_encoded.tail(10)
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 1305  0.069121             0              0          -0.427209 -0.239740
# 4083  0.112760             0              0          -0.310186 -0.779855
# 1495 -0.061796             0              0          -0.052600  0.212449
# 509  -0.149074             0              0          -0.487165  0.903293
# 4722  1.552852             1              0           1.013715  0.413422
# 4407 -0.367270             0              0          -0.796267  3.415455
# 2107  0.418234             1              0           1.409863 -0.164376
# 2228  0.243678             1              0           1.738063 -0.302545
# 998  -0.585466             0              0          -0.734091 -0.943146
# 1877 -1.720084             0              0          -0.640828 -1.282288
#
#       gender_Male  ever_married_Yes  work_type_Never_worked  \
# 1305         True              True                   False
# 4083        False              True                   False
# 1495        False              True                   False
# 509         False              True                   False
# 4722        False              True                   False
# 4407        False             False                   False
# 2107        False             False                   False
# 2228         True              True                   False
# 998         False             False                   False
# 1877        False             False                   False
#
#       work_type_Private  work_type_Self-employed  work_type_children  \
# 1305              False                    False               False
# 4083              False                     True               False
# 1495               True                    False               False
# 509                True                    False               False
# 4722              False                     True               False
# 4407               True                    False               False
# 2107               True                    False               False
# 2228               True                    False               False
# 998                True                    False               False
# 1877              False                    False                True
#
#       Residence_type_Urban  smoking_status_ordinal
# 1305                 False                     2.0
# 4083                  True                    -1.0
# 1495                 False                     2.0
# 509                  False                     2.0
# 4722                 False                     2.0
# 4407                  True                     1.0
# 2107                 False                     1.0
# 2228                  True                     2.0
# 998                   True                    -1.0
# 1877                 False                    -1.0

# %%
plt.scatter(
    x=X_train_encoded['bmi'],
    y=X_train_encoded['age'],
    c=y_train)
plt.savefig('before_resampling.png')
plt.show()

# %% [markdown]
# ## Random Oversampling

# %%
# Import RandomOverSampler from imblearn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the RandomOverSampler instance
random_oversampler = RandomOverSampler(random_state=1)

# Fit the data to the model
X_resampled, y_resampled = random_oversampler.fit_resample(X_train_encoded, y_train)

# %%
# Count distinct resampled values
y_resampled.value_counts()
# Out:
# stroke
# 0    3530
# 1    3530
# Name: count, dtype: int64

# %%
# 
X_train_encoded.head()
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 271   0.266619             0              0          -1.008950  0.317009
# 2604  0.757033             0              0          -0.383676 -0.002969
# 4894 -0.402127             0              0          -0.570535  2.211278
# 1372 -0.090045             0              0          -0.068551 -0.297349
# 3894 -1.892984             0              0          -0.540673 -1.372475
#
#       gender_Male  ever_married_Yes  work_type_Never_worked  \
# 271         False              True                   False
# 2604         True              True                   False
# 4894        False             False                   False
# 1372         True              True                   False
# 3894        False             False                   False
#
#       work_type_Private  work_type_Self-employed  work_type_children  \
# 271                True                    False               False
# 2604               True                    False               False
# 4894              False                    False               False
# 1372               True                    False               False
# 3894              False                    False                True
#
#       Residence_type_Urban  smoking_status_ordinal
# 271                  False                     0.0
# 2604                 False                     1.0
# 4894                  True                     2.0
# 1372                 False                    -1.0
# 3894                  True                     2.0

# %%
# Instantiate an initial RamdonForestClassifier instance
model = RandomForestClassifier(random_state = 42)

# Fit the initial model based the training data
model.fit(X_resampled, y_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions for testing features
y_pred = model.predict(X_test_encoded)

# %%
# Print the classification reports for the two models
print(classification_report(y_test, y_pred))
print(f"balanced accuracy score: {round(balanced_accuracy_score(y_test, y_pred),3)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1169
#            1       0.20      0.02      0.03        58
#
#     accuracy                           0.95      1227
#    macro avg       0.58      0.51      0.50      1227
# weighted avg       0.92      0.95      0.93      1227
#
# balanced accuracy score: 0.507

# %% [markdown]
# # SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_encoded, y_train)

# %%
y_train_resampled.value_counts()
# Out:
# stroke
# 0    3530
# 1    3530
# Name: count, dtype: int64

# %% [markdown]
# ### Logistic Regression

# %%
# Instantiate an initial logistic regression instance
lr_model = LogisticRegression(random_state = 42)

# Fit the initial model based the training data
lr_model.fit(X_train_resampled, y_train_resampled)

# Predict y data
y_pred_lr = lr_model.predict(X_test_encoded)

# %%
print(classification_report(y_test, y_pred_lr))
print(f"balanced accuracy score: {round(balanced_accuracy_score(y_test, y_pred_lr),3)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.74      0.84      1169
#            1       0.12      0.71      0.20        58
#
#     accuracy                           0.74      1227
#    macro avg       0.55      0.72      0.52      1227
# weighted avg       0.94      0.74      0.81      1227
#
# balanced accuracy score: 0.723

# %%
plt.scatter(
    x=X_train_resampled['bmi'],
    y=X_train_resampled['age'],
    c=y_train_resampled)

plt.savefig('after_resampling.png')
plt.show()

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_model = AdaBoostClassifier()
ada_model.fit(X_train_resampled, y_train_resampled)
y_pred_ada = ada_model.predict(X_test_encoded)
# Out:
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
print(classification_report(y_test, y_pred_ada))
print(f"balanced accuracy score: {round(balanced_accuracy_score(y_test, y_pred_ada),3)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.73      0.84      1169
#            1       0.12      0.72      0.20        58
#
#     accuracy                           0.73      1227
#    macro avg       0.55      0.73      0.52      1227
# weighted avg       0.94      0.73      0.81      1227
#
# balanced accuracy score: 0.728

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 150, 200, 300],  
    'learning_rate': [0.01, 0.1, 1.0] 
}

# %%
# Perform the grid search 
grid_search = GridSearchCV(estimator=ada_model, param_grid=param_grid, 
                           scoring='balanced_accuracy', cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)
# Out:
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\jclib\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1.0],
#                          'n_estimators': [50, 100, 150, 200, 300]},
#              scoring='balanced_accuracy')

# %%
# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best Cross-Validation Balanced Accuracy Score: {best_score}")
# Out:
# Best Parameters: {'learning_rate': 1.0, 'n_estimators': 300}
# Best Cross-Validation Balanced Accuracy Score: 0.8490084985835693
